# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()

df=pd.read_csv("dataset.csv")
# Out:
#      <input type="file" id="files-502df79e-173c-4d01-9dcb-b4071fbfe4c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-502df79e-173c-4d01-9dcb-b4071fbfe4c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#    VIN (1-10)     County      City State  Postal Code  Model Year       Make  \
# 0  JTMEB3FV6N     Monroe  Key West    FL        33040        2022     TOYOTA
# 1  1G1RD6E45D      Clark  Laughlin    NV        89029        2013  CHEVROLET
# 2  JN1AZ0CP8B     Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H     Skagit  Concrete    WA        98237        2017  CHEVROLET
# 4  3FA6P0SU1K  Snohomish   Everett    WA        98201        2019       FORD
#
#         Model                   Electric Vehicle Type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     BOLT EV          Battery Electric Vehicle (BEV)
# 4      FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible              42
# ...

# %%
df.tail()
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 112629  7SAYGDEF2N      King         Duvall    WA        98019        2022
# 112630  1N4BZ1CP7K  San Juan  Friday Harbor    WA        98250        2019
# 112631  1FMCU0KZ4N      King         Vashon    WA        98070        2022
# 112632  KNDCD3LD4J      King      Covington    WA        98042        2018
# 112633  YV4BR0CL8N      King      Covington    WA        98042        2022
#
#           Make    Model                   Electric Vehicle Type  \
# 112629   TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 112630  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 112631    FORD   ESCAPE  Plug-in Hybrid Electric Vehicle (PHEV)
# 112632     KIA     NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
# 112633   VOLVO     XC90  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112634 entries, 0 to 112633
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         112634 non-null  object
#  1   County                                             112634 non-null  object
#  2   City                                               112634 non-null  object
#  3   State                                              112634 non-null  object
#  4   Postal Code                                        112634 non-null  int64
#  5   Model Year                                         112634 non-null  int64
#  6   Make                                               112634 non-null  object
#  7   Model                                              112614 non-null  object
# ...

# %%
print(df.describe().transpose())
# Out:
#                          count          mean           std           min  \
# postal_code           112634.0  9.815623e+04  2.648733e+03  1.730000e+03
# model_year            112634.0  2.019003e+03  2.892364e+00  1.997000e+03
# electric_range        112634.0  8.781299e+01  1.023342e+02  0.000000e+00
# base_msrp             112634.0  1.793440e+03  1.078375e+04  0.000000e+00
# legislative_district  112348.0  2.980560e+01  1.470055e+01  1.000000e+00
# dol_vehicle_id        112634.0  1.994567e+08  9.398427e+07  4.777000e+03
# 2020_census_tract     112634.0  5.296650e+10  1.699104e+09  1.101001e+09
#
#                                25%           50%           75%           max
# postal_code           9.805200e+04  9.811900e+04  9.837000e+04  9.970100e+04
# model_year            2.017000e+03  2.020000e+03  2.022000e+03  2.023000e+03
# electric_range        0.000000e+00  3.200000e+01  2.080000e+02  3.370000e+02
# base_msrp             0.000000e+00  0.000000e+00  0.000000e+00  8.450000e+05
# ...

# %%
df.shape
# Out:
# (112634, 17)

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns
# Out:
# Index(['VIN_(1-10)', 'County', 'City', 'State', 'Postal_Code', 'Model_Year',
#        'Make', 'Model', 'Electric_Vehicle_Type',
#        'Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility', 'Electric_Range',
#        'Base_MSRP', 'Legislative_District', 'DOL_Vehicle_ID',
#        'Vehicle_Location', 'Electric_Utility', '2020_Census_Tract'],
#       dtype='object')

# %%
df.rename(columns={'Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility':'CAFV_Eligibility'}, inplace=True)
df.columns
# Out:
# Index(['VIN_(1-10)', 'County', 'City', 'State', 'Postal_Code', 'Model_Year',
#        'Make', 'Model', 'Electric_Vehicle_Type', 'CAFV_Eligibility',
#        'Electric_Range', 'Base_MSRP', 'Legislative_District', 'DOL_Vehicle_ID',
#        'Vehicle_Location', 'Electric_Utility', '2020_Census_Tract'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['vin_(1-10)', 'county', 'city', 'state', 'postal_code', 'model_year',
#        'make', 'model', 'electric_vehicle_type', 'cafv_eligibility',
#        'electric_range', 'base_msrp', 'legislative_district', 'dol_vehicle_id',
#        'vehicle_location', 'electric_utility', '2020_census_tract'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# vin_(1-10)                 0
# county                     0
# city                       0
# state                      0
# postal_code                0
# model_year                 0
# make                       0
# model                     20
# electric_vehicle_type      0
# cafv_eligibility           0
# electric_range             0
# base_msrp                  0
# legislative_district     286
# dol_vehicle_id             0
# vehicle_location          24
# electric_utility         443
# 2020_census_tract          0
# dtype: int64

# %%
df_dropna = df.dropna()

df_dropna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 112152 entries, 2 to 112633
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   vin_(1-10)             112152 non-null  object
#  1   county                 112152 non-null  object
#  2   city                   112152 non-null  object
#  3   state                  112152 non-null  object
#  4   postal_code            112152 non-null  int64
#  5   model_year             112152 non-null  int64
#  6   make                   112152 non-null  object
#  7   model                  112152 non-null  object
#  8   electric_vehicle_type  112152 non-null  object
#  9   cafv_eligibility       112152 non-null  object
#  10  electric_range         112152 non-null  int64
#  11  base_msrp              112152 non-null  int64
#  12  legislative_district   112152 non-null  float64
#  13  dol_vehicle_id         112152 non-null  int64
# ...

# %%
df.head()
# Out:
#    vin_(1-10)     county      city state  postal_code  model_year       make  \
# 0  JTMEB3FV6N     Monroe  Key West    FL        33040        2022     TOYOTA
# 1  1G1RD6E45D      Clark  Laughlin    NV        89029        2013  CHEVROLET
# 2  JN1AZ0CP8B     Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H     Skagit  Concrete    WA        98237        2017  CHEVROLET
# 4  3FA6P0SU1K  Snohomish   Everett    WA        98201        2019       FORD
#
#         model                   electric_vehicle_type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     BOLT EV          Battery Electric Vehicle (BEV)
# 4      FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
#
#                           cafv_eligibility  electric_range  base_msrp  \
# 0  Clean Alternative Fuel Vehicle Eligible              42          0
# ...

# %%
numerical_columns = ['postal_code', 'model_year', 'electric_range', 'base_msrp', 'legislative_district', 'dol_vehicle_id', '2020_census_tract']

categorical_columns = ['vin_(1-10)', 'county', 'city', 'state', 'make', 'model', 'electric_vehicle_type', 'cafv_eligibility', 'vehicle_location', 'electric_utility']

# %%
import plotly.express as px
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


for column in numerical_columns:
    plt.figure(figsize=(8,6))
    sns.boxplot(x=df[column])
    plt.title(f"Boxplot for {column}")  # Fixed string concatenation
    plt.grid()
    plt.show()
    print(f"Displayed boxplot for {column}")
# Out:
# Displayed boxplot for postal_code
# Displayed boxplot for model_year
# Displayed boxplot for electric_range
# Displayed boxplot for base_msrp
# Displayed boxplot for legislative_district
# Displayed boxplot for dol_vehicle_id
# Displayed boxplot for 2020_census_tract

# %%
for column in numerical_columns:
    plt.figure(figsize=(8,6))
    sns.kdeplot(x=df[column])
    plt.title(f"kdeplot for {column}")  # Fixed string concatenation
    plt.grid()
    plt.show()
    print(f"Displayed kdeplot for {column}")
# Out:
# Displayed kdeplot for postal_code
# Displayed kdeplot for model_year
# Displayed kdeplot for electric_range
# Displayed kdeplot for base_msrp
# Displayed kdeplot for legislative_district
# Displayed kdeplot for dol_vehicle_id
# Displayed kdeplot for 2020_census_tract

# %%
for column in categorical_columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(data=df, x=column, order=df[column].value_counts().index)  # Order by counts
    plt.title(f"Count Plot for {column}")
    plt.xlabel(column)
    plt.ylabel("Count")
    plt.xticks(rotation=45)  # Rotate x-ticks if they overlap
    plt.show()
    print(f"Displayed count plot for {column}")
# Out:
# Displayed count plot for vin_(1-10)
# Displayed count plot for county
# Displayed count plot for city
# Displayed count plot for state
# Displayed count plot for make
# Displayed count plot for model
# Displayed count plot for electric_vehicle_type
# Displayed count plot for cafv_eligibility
# Displayed count plot for vehicle_location
# Displayed count plot for electric_utility

# %%
for column in categorical_columns:
    plt.figure(figsize=(8, 6))
    counts = df[column].value_counts()
    sns.barplot(x=counts.index, y=counts.values)
    plt.title(f"Bar Plot for {column}")
    plt.xlabel(column)
    plt.ylabel("Count")
    plt.xticks(rotation=45)  # Rotate x-ticks if they overlap
    plt.show()
    print(f"Displayed bar plot for {column}")
# Out:
# Displayed bar plot for vin_(1-10)
# Displayed bar plot for county
# Displayed bar plot for city
# Displayed bar plot for state
# Displayed bar plot for make
# Displayed bar plot for model
# Displayed bar plot for electric_vehicle_type
# Displayed bar plot for cafv_eligibility
# Displayed bar plot for vehicle_location
# Displayed bar plot for electric_utility

# %%
for column in categorical_columns:
    plt.figure(figsize=(8, 6))

    # Get the top five categories by count
    counts = df[column].value_counts().nlargest(5)  # Get top 5 categories
    plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)

    plt.title(f"Pie Chart for Top 5 Categories in {column}")
    plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
    plt.show()

    print(f"Displayed pie chart for top 5 categories in {column}")
# Out:
# Displayed pie chart for top 5 categories in vin_(1-10)
# Displayed pie chart for top 5 categories in county
# Displayed pie chart for top 5 categories in city
# Displayed pie chart for top 5 categories in state
# Displayed pie chart for top 5 categories in make
# Displayed pie chart for top 5 categories in model
# Displayed pie chart for top 5 categories in electric_vehicle_type
# Displayed pie chart for top 5 categories in cafv_eligibility
# Displayed pie chart for top 5 categories in vehicle_location
# Displayed pie chart for top 5 categories in electric_utility

# %%
import plotly.express as px

# Grouping the data by state and counting the number of electric vehicles
state_data = df.groupby('state')['vin_(1-10)'].count().reset_index()
state_data.columns = ['state', 'ev_count']

# Creating the choropleth map
fig = px.choropleth(
    state_data,
    locations='state',
    locationmode='USA-states',
    color='ev_count',
    color_continuous_scale="YlGn",
    scope='usa',
    labels={'ev_count': 'Number of EV Vehicles'},  # Corrected labels syntax
    title='Number of Electric Vehicles by State'
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112634 entries, 0 to 112633
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   vin_(1-10)             112634 non-null  object
#  1   county                 112634 non-null  object
#  2   city                   112634 non-null  object
#  3   state                  112634 non-null  object
#  4   postal_code            112634 non-null  int64
#  5   model_year             112634 non-null  int64
#  6   make                   112634 non-null  object
#  7   model                  112614 non-null  object
#  8   electric_vehicle_type  112634 non-null  object
#  9   cafv_eligibility       112634 non-null  object
#  10  electric_range         112634 non-null  int64
#  11  base_msrp              112634 non-null  int64
#  12  legislative_district   112348 non-null  float64
#  13  dol_vehicle_id         112634 non-null  int64
# ...

# %%
# !pip install bar-chart-race
# !apt-get install ffmpeg
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 3.0 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
df.columns
# Out:
# Index(['vin_(1-10)', 'county', 'city', 'state', 'postal_code', 'model_year',
#        'make', 'model', 'electric_vehicle_type', 'cafv_eligibility',
#        'electric_range', 'base_msrp', 'legislative_district', 'dol_vehicle_id',
#        'vehicle_location', 'electric_utility', '2020_census_tract'],
#       dtype='object')

# %%
import pandas as pd
import bar_chart_race as bcr

ev_made_year = df.groupby(['model_year', 'make']).size().reset_index(name='ev_count')

# Pivoting the DataFrame for the bar chart race
pivot_df = ev_made_year.pivot(index='model_year', columns='make', values='ev_count').fillna(0)

# Creating the bar chart race
bcr.bar_chart_race(
    df=pivot_df,
    title='Number of Electric Vehicles by Car Make Over Years',
    filename='ev_bar_chart_race.mp4',  # Save the animation as a video file
    steps_per_period=10,  # Number of frames to show per time period
    period_length=1000,  # Length of time to display each period in milliseconds
    sort='desc',  # Sort the bars in descending order
    n_bars=5,  # Number of bars to display
    period_label={'x': 0.99, 'y': 0.9, 'ha': 'right', 'va': 'center'},  # Position of the period label
    bar_label_size=7,  # Size of the labels on the bars
    tick_label_size=7,  # Size of the tick labels
    figsize=(5, 3)  # Figure size
)
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:889: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:226: UserWarning:
#
# Some of your columns never make an appearance in the animation. To reduce color repetition, set `filter_column_colors` to `True`

# %%
from google.colab import files
files.download('ev_bar_chart_race.mp4')
